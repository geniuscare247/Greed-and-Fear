# %%
import pandas as pd
import numpy as np
from pathlib import Path

############################

# Vinit commented out code below
# from google.colab import drive
# drive.mount('/content/drive')


#_here = Path.cwd()
# DATA = _here / "data_splits"
# if not DATA.exists():
#     DATA = _here / "207" / "207 project" / "Greed-and-Fear" / "data_splits"

######################################

# Vinit added code below
from google.colab import drive
drive.mount('/content/drive')

DATA = Path("/content/drive/MyDrive/Colab Notebooks")

######################################


FEAT = "trailing_vol_annual_decimel_20d_calculated"
TGT = "y_known_at_t"
FWD = "forward_vol_5d_annual_decimel_calculated"
TRAIN_FN = "vol_dataset_train_20150102_20221230.csv"
VAL_FN = "vol_dataset_validation_20230103_20241231.csv"
TEST_FN = "vol_dataset_test_20250102_20251231.csv"

def load_split(fn):
    p = DATA / fn
    df = pd.read_csv(p, low_memory=False)
    if "date" in df.columns:
        df["date"] = pd.to_datetime(df["date"], format="mixed", errors="coerce")
    return df


def eda_one(name, df):
    n = len(df)
    na_f = df[FEAT].isna().sum()
    na_y = df[TGT].isna().sum()
    na_fwd = int(df[FWD].isna().sum()) if FWD in df.columns else None
    m_feat = df[FEAT].isna()
    m_tgt = df[TGT].isna()
    only_feat = int((m_feat & ~m_tgt).sum())
    only_tgt = int((~m_feat & m_tgt).sum())
    both = int((m_feat & m_tgt).sum())
    either = int((m_feat | m_tgt).sum())
    d = df.dropna(subset=[FEAT, TGT])


d_tr = load_split(TRAIN_FN)
d_va = load_split(VAL_FN)
d_te = load_split(TEST_FN)
eda_one(TRAIN_FN, d_tr)
eda_one(VAL_FN, d_va)
eda_one(TEST_FN, d_te)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
#


# VB changed below to random_seed(42)
tf.keras.utils.set_random_seed(42)

SEQ = 5


def make_sequences(X, y, time_steps):
    xs, ys = [], []
    for i in range(len(X) - time_steps):
        xs.append(X.iloc[i : i + time_steps].values)
        ys.append(y.iloc[i + time_steps])
    return np.array(xs), np.array(ys)


def stack_sequences(df):
    x_list, y_list = [], []
    for _, g in df.groupby("ticker", sort=False):
        g = g.sort_values("date")
        g = g.dropna(subset=[FEAT, TGT])
        if len(g) <= SEQ:
            continue
        X = g[[FEAT]]
        y = g[TGT]
        xa, ya = make_sequences(X, y, SEQ)
        if len(xa):
            x_list.append(xa)
            y_list.append(ya)
    if not x_list:
        return np.empty((0, SEQ, 1)), np.array([])
    return np.vstack(x_list), np.concatenate(y_list)


X_tr_s, y_tr_s = stack_sequences(d_tr)
X_va_s, y_va_s = stack_sequences(d_va)
X_te_s, y_te_s = stack_sequences(d_te)

sc = StandardScaler()
nfeat = X_tr_s.shape[-1]
X_tr_sc = sc.fit_transform(X_tr_s.reshape(-1, nfeat)).reshape(X_tr_s.shape)
X_va_sc = sc.transform(X_va_s.reshape(-1, nfeat)).reshape(X_va_s.shape)
X_te_sc = sc.transform(X_te_s.reshape(-1, nfeat)).reshape(X_te_s.shape)

##################################################

# Vinit commented out this code
# shape_in = (X_tr_sc.shape[1], X_tr_sc.shape[2])
# model = tf.keras.Sequential([
#    tf.keras.layers.LSTM(50, activation="relu", input_shape=shape_in, return_sequences=True),
#    tf.keras.layers.LSTM(50, activation="relu"),
#    tf.keras.layers.Dense(1),
# ])

###################################################

# Vinit added this code

shape_in = (X_tr_s.shape[1], X_tr_s.shape[2])

model = tf.keras.Sequential([
    tf.keras.Input(shape=shape_in),
    tf.keras.layers.LSTM(50, activation="relu", return_sequences=True),
    tf.keras.layers.LSTM(50, activation="relu"),
    tf.keras.layers.Dense(1),
])


##################################################







model.compile(optimizer="adam", loss="mse", metrics=["mae", "mse"])
model.fit(X_tr_sc, y_tr_s, validation_data=(X_va_sc, y_va_s), epochs=30, batch_size=32, verbose=1)
pred = model.predict(X_te_sc, verbose=0).flatten()
mae = mean_absolute_error(y_te_s, pred)
rmse = float(np.sqrt(mean_squared_error(y_te_s, pred)))
print("mae", mae, "rmse", rmse)
print("seq_shapes train val test", X_tr_s.shape, X_va_s.shape, X_te_s.shape)
# Out:
# Epoch 1/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 0.0093 - mae: 0.0637 - mse: 0.0093 - val_loss: 0.0048 - val_mae: 0.0520 - val_mse: 0.0048
# Epoch 2/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - loss: 0.0067 - mae: 0.0550 - mse: 0.0067 - val_loss: 0.0051 - val_mae: 0.0531 - val_mse: 0.0051
# Epoch 3/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 40s 10ms/step - loss: 0.0061 - mae: 0.0526 - mse: 0.0061 - val_loss: 0.0045 - val_mae: 0.0500 - val_mse: 0.0045
# Epoch 4/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - loss: 0.0055 - mae: 0.0503 - mse: 0.0055 - val_loss: 0.0036 - val_mae: 0.0445 - val_mse: 0.0036
# Epoch 5/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0052 - mae: 0.0488 - mse: 0.0052 - val_loss: 0.0034 - val_mae: 0.0428 - val_mse: 0.0034
# Epoch 6/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 0.0050 - mae: 0.0477 - mse: 0.0050 - val_loss: 0.0033 - val_mae: 0.0415 - val_mse: 0.0033
# Epoch 7/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0049 - mae: 0.0472 - mse: 0.0049 - val_loss: 0.0032 - val_mae: 0.0407 - val_mse: 0.0032
# Epoch 8/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0048 - mae: 0.0464 - mse: 0.0048 - val_loss: 0.0032 - val_mae: 0.0408 - val_mse: 0.0032
# Epoch 9/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0047 - mae: 0.0460 - mse: 0.0047 - val_loss: 0.0032 - val_mae: 0.0407 - val_mse: 0.0032
# Epoch 10/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0047 - mae: 0.0457 - mse: 0.0047 - val_loss: 0.0033 - val_mae: 0.0412 - val_mse: 0.0033
# Epoch 11/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0046 - mae: 0.0455 - mse: 0.0046 - val_loss: 0.0032 - val_mae: 0.0405 - val_mse: 0.0032
# Epoch 12/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0046 - mae: 0.0454 - mse: 0.0046 - val_loss: 0.0032 - val_mae: 0.0407 - val_mse: 0.0032
# Epoch 13/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0045 - mae: 0.0451 - mse: 0.0045 - val_loss: 0.0031 - val_mae: 0.0403 - val_mse: 0.0031
# Epoch 14/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0045 - mae: 0.0449 - mse: 0.0045 - val_loss: 0.0032 - val_mae: 0.0407 - val_mse: 0.0032
# Epoch 15/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0045 - mae: 0.0448 - mse: 0.0045 - val_loss: 0.0032 - val_mae: 0.0403 - val_mse: 0.0032
# Epoch 16/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 0.0045 - mae: 0.0447 - mse: 0.0045 - val_loss: 0.0032 - val_mae: 0.0406 - val_mse: 0.0032
# Epoch 17/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0045 - mae: 0.0446 - mse: 0.0045 - val_loss: 0.0032 - val_mae: 0.0404 - val_mse: 0.0032
# Epoch 18/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0044 - mae: 0.0445 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0398 - val_mse: 0.0031
# Epoch 19/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 0.0044 - mae: 0.0444 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0402 - val_mse: 0.0031
# Epoch 20/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0044 - mae: 0.0444 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0403 - val_mse: 0.0031
# Epoch 21/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0044 - mae: 0.0443 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0398 - val_mse: 0.0031
# Epoch 22/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - loss: 0.0044 - mae: 0.0442 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0396 - val_mse: 0.0031
# Epoch 23/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0044 - mae: 0.0441 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0396 - val_mse: 0.0031
# Epoch 24/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0044 - mae: 0.0441 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0398 - val_mse: 0.0031
# Epoch 25/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 0.0044 - mae: 0.0441 - mse: 0.0044 - val_loss: 0.0031 - val_mae: 0.0398 - val_mse: 0.0031
# Epoch 26/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0043 - mae: 0.0440 - mse: 0.0043 - val_loss: 0.0031 - val_mae: 0.0396 - val_mse: 0.0031
# Epoch 27/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 0.0043 - mae: 0.0440 - mse: 0.0043 - val_loss: 0.0031 - val_mae: 0.0395 - val_mse: 0.0031
# Epoch 28/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 0.0043 - mae: 0.0439 - mse: 0.0043 - val_loss: 0.0030 - val_mae: 0.0393 - val_mse: 0.0030
# Epoch 29/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0043 - mae: 0.0439 - mse: 0.0043 - val_loss: 0.0031 - val_mae: 0.0395 - val_mse: 0.0031
# Epoch 30/30
# 2143/2143 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0043 - mae: 0.0438 - mse: 0.0043 - val_loss: 0.0031 - val_mae: 0.0395 - val_mse: 0.0031
# mae 0.04760030895983822 rmse 0.07277151041799883
# seq_shapes train val test (68553, 5, 1) (17892, 5, 1) (8820, 5, 1)
